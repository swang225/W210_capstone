# %%
import torch
import torch.nn as nn
import clip
from PIL import Image
import pandas as pd
import requests
import os.path as osp
import pickle
import random
import numpy as np
from pathlib import Path
import sys
from operator import itemgetter
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time

# %%
class Timer:
    def __init__(self):

        self.t1 = None

    @staticmethod
    def delta_to_string(td):

        res_list = []

        def format():
            return ", ".join(reversed(res_list)) + " elapsed."

        seconds = td % 60
        td //= 60
        res_list.append(f"{round(seconds,3)} seconds")

        if td <= 0:
            return format()

        minutes = td % 60
        td //= 60
        res_list.append(f"{minutes} minutes")

        if td <= 0:
            return format()

        hours = td % 24
        td //= 24
        res_list.append(f"{hours} hours")

        if td <= 0:
            return format()

        res_list.append(f"{td} days")

        return format()

    def __enter__(self):

        self.t1 = time.time()

    def __exit__(self, *args, **kwargs):

        t2 = time.time()
        td = t2 - self.t1

        print(self.delta_to_string(td))

# %%
def image_path(uid):
    return osp.join(image_storage, f"{uid}.jpg")

# %%
def read_pickle(dir):
    with open(dir, 'rb') as handle:
        b = pickle.load(handle)
    return b


def write_pickle(dir, data):
    with open(dir, 'wb') as handle:
        pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
dataset_path = "C:/Users/aphri/Documents/t0002/work/data/w210_data/target_store_furniture_datasets.csv"
image_storage = "C:/Users/aphri/Documents/t0002/work/data/w210_data/target_images"
pickle_path = "C:/Users/aphri/Documents/t0002/work/data/w210_data/pickle"
model_path = "C:/Users/aphri/Documents/t0002/work/data/w210_data/model"

Path(image_storage).mkdir(parents=True, exist_ok=True)
Path(pickle_path).mkdir(parents=True, exist_ok=True)
Path(model_path).mkdir(parents=True, exist_ok=True)

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

# %%
d1 = pd.read_csv(dataset_path)

# %%
uid = d1.iloc[0]["uniq_id"]
path = image_path(uid)

# %%
image = Image.open(path)

# %%
file = osp.join(pickle_path, "1000.pkl")
data = read_pickle(file)

# %%
data_pickles = [
    1000, 2000, 3000, 4000, 5000, 6000, 
    7000, 8000, 9000, 10000, 11000, 12000, 
    13000, 14000, 15000, 16000, 17000, 18000, 
    19000, 20000, 21000, 22000, 23000, 24000, 
    25000, 26000, 27000, 28000, 29000, 30000, 
    31000, 32000, 33000, 34000, 35000, 36000, 
    37000, 38000, 39000, 40000, 41000, 42215
]

data_list = []
for p in data_pickles:
    file = osp.join(pickle_path, f"{p}.pkl")
    data = read_pickle(file)
    data_list.append(data)

# %%
data_list[0].head()
# Out:
#                                     uid               text  \
# 0  c456e14d-0693-5552-8f90-eead4a0f1f50              Desks
# 1  b020d91e-77ab-5c3e-b1e6-2fe01abe41b6           Dressers
# 2  d0972ad8-c10a-5d84-86a1-4d25cd361229               Beds
# 3  dade134d-f251-5120-97be-23eb1e01c0f8  Storage Furniture
# 4  f2e0d558-e93f-541b-98b1-6fff36f1dc89       Patio Chairs
#
#                                        encoded_image  \
# 0  [[[tensor([1.9303, 1.9303, 1.9303, 1.9303, 1.9...
# 1  [[[tensor([1.9303, 1.9303, 1.9303, 1.9303, 1.9...
# 2  [[[tensor([1.9303, 1.9303, 1.9303, 1.9303, 1.9...
# 3  [[[tensor([1.9303, 1.9303, 1.9303, 1.9303, 1.9...
# 4  [[[tensor([1.9303, 1.9303, 1.9303, 1.9303, 1.9...
#
#                                         encoded_text
# 0  [[tensor(49406, dtype=torch.int32), tensor(410...
# 1  [[tensor(49406, dtype=torch.int32), tensor(126...
# 2  [[tensor(49406, dtype=torch.int32), tensor(139...
# 3  [[tensor(49406, dtype=torch.int32), tensor(682...
# 4  [[tensor(49406, dtype=torch.int32), tensor(143...

# %%
def find_products(text_input, data):
    print(f"finding products for query: {text_input}...")
    text_input = [text_input]
    
    data = data[~data["encoded_image"].isna()]
    image_uids = list(data["uid"].values)
    
    encoded_images = torch.cat(list(data["encoded_image"].values)).to(device)
    encoded_texts = clip.tokenize(text_input).to(device)
    
    with torch.no_grad():
        logits_per_image, logits_per_text = model(encoded_images, encoded_texts)
        probs = logits_per_text.softmax(dim=-1).cpu().numpy()
    
    res = dict(zip(image_uids, probs[0] * 100))
    res = dict(sorted(res.items(), key=itemgetter(1), reverse=True)[:5])
    
    return res


def show_images(res):
    n = len(res)
    fig, ax = plt.subplots(1, n)

    fig.set_figheight(5)
    fig.set_figwidth(5 * n)

    for i, image in enumerate(res.keys()):
        img_path = image_path(image)
        img = mpimg.imread(img_path)
        ax[i].imshow(img)
        ax[i].axis('off')
        # ax[i].set_title(get_label(image), fontsize=8)

    plt.subplots_adjust(wspace=0, hspace=0.1)

# %%
text_input = "I am looking for a large beige office chair"
data = data_list[0]

with Timer():
    res1 = find_products(text_input, data)

print(res1)
show_images(res1)
# Out:
# 1.0 minutes, 41.426 seconds elapsed.
# {'8418e43d-3e12-597e-b446-ae483cf22327': 8.326147, 'a944a77b-e740-5ca0-9c59-4d53ab8f2b58': 7.440852, 'a6d19fa8-f218-53eb-b9fc-280c91a8930f': 7.198289, '71124924-6927-569a-9c40-b695e95d5187': 6.943235, '1e4d05fe-8d63-550a-afca-25b61ed95e43': 5.859204}

# %%
text_input = "I am looking for a large black office chair"
data = data_list[0]

with Timer():
    res1 = find_products(text_input, data)

print(res1)
show_images(res1)
# Out:
# finding products for query: I am looking for a large black office chair...

# %%
r1 = set(d1["sub_category_1"].dropna().values)
r1
# Out:
# {'Accessories',
#  'Action Figures & Playsets',
#  'Amplifiers & Effects',
#  'Automotive',
#  'Baby Safety',
#  'Bar & Wine',
#  'Bathroom Furniture',
#  'Bedroom Furniture',
#  'Boards & Easels',
#  'Books',
#  'Camping Gear',
#  'Cat Supplies',
#  'Christmas',
#  'Cleaning Supplies',
#  'Decor Style Ideas',
#  'Desk Organization',
#  'Dog Supplies',
#  'Dolls & Dollhouses',
#  'Dorm Furniture',
#  'Dress Up & Pretend Play',
#  'Entryway Furniture & Organization',
#  'Fall Lawn Cleanup',
#  'Fire Pits & Patio Heaters',
#  'Furniture Deal of the Day',
#  'Furniture Ways to Shop',
#  'Heating, Cooling & Air Quality',
#  'Home Appliances',
#  'Home Deals',
#  'Home Decor',
#  'Home Improvement',
#  'Home Office Furniture',
#  "Kids' Crafts",
#  "Kids' Home",
#  'Kitchen & Dining Furniture',
#  'Kitchen & Table Linens',
#  'Laundry Care',
#  'Lawn & Garden',
#  'Living Room Furniture',
#  'Music',
#  'Nintendo Switch',
#  'Nursery',
#  'Outdoor Decor',
#  'Outdoor Dining',
#  'Outdoor Recreation',
#  'Outdoor Shade & Structures',
#  'Packing & Mailing Supplies',
#  'Patio Furniture',
#  'Small Space Furniture',
#  'Sports & Outdoors Deals',
#  'Storage & Organization',
#  'Tech Services & Support',
#  'Toy Deals'}

# %%
r2 = set(d1["sub_category_2"].dropna().values)
r2
# Out:
# {'Action Figure Playsets',
#  'Action Figures',
#  'Adult Accessories',
#  'All Book Genres',
#  'Amplifiers & Effects Accessories',
#  'Armoires & Wardrobes',
#  'Baby Dolls',
#  'Baby Proofing',
#  "Bakers' Racks & Pantry Cabinets",
#  'Bar & Wine Tools',
#  'Bar Carts',
#  'Bar Stools & Counter Stools',
#  'Bars & Wine Racks',
#  'Bed Frames',
#  'Bedroom Sets & Collections',
#  'Beds',
#  'Book Pre-orders',
#  'Bookshelves & Bookcases',
#  'Camping Chairs & Furniture',
#  'Car Cleaning',
#  'Cat Health & Grooming',
#  'Cat Litter & Supplies',
#  'Cat Scratchers, Trees & Towers',
#  'Chair Pads',
#  'Chairs',
#  'Cleaning Tools',
#  'Coat Racks',
#  'Coffee Tables',
#  'Console Tables',
#  'Couch Covers & Furniture Covers',
#  'Daybeds & Chaise Lounges',
#  'Decorative Objects & Sculptures',
#  'Decorative Storage',
#  'Desks',
#  'Dining Chairs & Benches',
#  'Dining Room Sets & Collections',
#  'Dining Tables',
#  'Dog Beds',
#  'Doll Clothes & Accessories',
#  'Doll Furniture',
#  'Doll Playsets',
#  'Dollhouses',
#  'Dressers',
#  'Easels & Activity Tables',
#  'End & Side Tables',
#  'Fashion Dolls',
#  'Filing Cabinets',
#  'Folding Tables & Chairs',
#  'Furniture Deals',
#  'Futons',
#  'Hammocks',
#  'Hardware',
#  'Headboards',
#  'Heaters',
#  'Home Office Furniture Accessories',
#  'Home Office Sets & Collections',
#  'Home Renovation',
#  'Indoor Christmas Decorations',
#  'Irons, Steamers & Accessories',
#  'Jewelry Armoires',
#  "Kids' Books",
#  "Kids' Furniture",
#  'Kitchen Carts & Islands',
#  'Lamps & Lighting',
#  'Living Room Sets & Collections',
#  'Loveseats',
#  'Modern Decor',
#  'New Books',
#  'Nightstands',
#  'Nintendo Switch Games',
#  'Non-Fiction',
#  'Nursery Furniture',
#  'Office Chairs',
#  'Ottomans & Benches',
#  'Outdoor Benches',
#  'Outdoor Heating Accessories',
#  'Outdoor Ottomans & Poufs',
#  'Outdoor Sectionals',
#  'Outdoor Sofas & Loveseats',
#  'Packaging Supplies',
#  'Patio Bars & Carts',
#  'Patio Chairs',
#  'Patio Furniture Covers',
#  'Patio Sets',
#  'Patio Tables',
#  'Picture Frames',
#  'Play Tents',
#  'Presentation Boards',
#  'Protection Plans',
#  'Room Dividers',
#  'Rugs',
#  'Sectional Sofas',
#  'Sideboards & Buffet Tables',
#  'Small Space Patio Furniture',
#  'Sofa Beds',
#  'Sofas & Couches',
#  'Statement Furniture',
#  'Storage Bins & Boxes',
#  'Storage Furniture',
#  'Swimming Pools',
#  'TV Stands & Entertainment Centers',
#  "Teens' Books",
#  'Vanities',
#  'Vinyl Records',
#  'Wall Decor'}
